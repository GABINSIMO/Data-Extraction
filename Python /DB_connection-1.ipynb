# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (9.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Connection a mon DB

# %%
import mysql.connector
import pandas as pd

conn = mysql.connector.connect(
    host="localhost",
    user="python_user", 
    password="",          
    database="Extraction",
    port=3306
)

df = pd.read_sql("""
                    SELECT table_name,
                           table_type
                    FROM information_schema.tables
                    WHERE table_schema = DATABASE();
                """, conn)
                
print(df1)

conn.close()
# Out:
#          TABLE_NAME  TABLE_TYPE
# 0          docteurs  BASE TABLE
# 1          factures  BASE TABLE
# 2          patients  BASE TABLE
# 3  profil_financier        VIEW
# 4    profil_medical        VIEW
# 5     profil_social        VIEW
# 6               rdv  BASE TABLE
# 7       traitements  BASE TABLE
# /var/folders/p1/fz80s89n6wddct18pzpbmc540000gn/T/ipykernel_68418/3170172589.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SHOW TABLES;", conn)
# /var/folders/p1/fz80s89n6wddct18pzpbmc540000gn/T/ipykernel_68418/3170172589.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1 = pd.read_sql("""
